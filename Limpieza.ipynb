# %%
import pandas as pd
import numpy as np

# %%
train_raw= pd.read_csv("D:\Bootcamp\competencia1\_Train__202304301950.csv")
train_raw
# Out:
#      laptop_ID Company                               Product   TypeName  \
# 0         1104    Acer                        Aspire ES1-523   Notebook
# 1          114    Dell                                XPS 13  Ultrabook
# 2          172    Acer                       Aspire A517-51G   Notebook
# 3          918      HP                         Elitebook 820    Netbook
# 4          447  Lenovo                     IdeaPad 320-15AST   Notebook
# ..         ...     ...                                   ...        ...
# 907        996  Lenovo                     IdeaPad 320-15ABR   Notebook
# 908        731    Dell                          Alienware 17     Gaming
# 909        276    Asus                             Rog Strix     Gaming
# 910        585     MSI                          GT73VR Titan     Gaming
# 911       1173      HP  15-bw002nv (A6-9220/4GB/256GB/Radeon   Notebook
#
#      Inches                  ScreenResolution                           Cpu  \
# ...

# %%
train_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 912 entries, 1104 to 1173
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           912 non-null    object
#  1   Product           912 non-null    object
#  2   TypeName          912 non-null    object
#  3   Inches            912 non-null    float64
#  4   ScreenResolution  912 non-null    object
#  5   Cpu               912 non-null    object
#  6   Ram               912 non-null    object
#  7   Memory            912 non-null    object
#  8   Gpu               912 non-null    object
#  9   OpSys             912 non-null    object
#  10  Weight            912 non-null    object
#  11  Price_euros       912 non-null    float64
#  12  column1           0 non-null      float64
# dtypes: float64(3), object(10)
# memory usage: 99.8+ KB

# %%
train_raw.describe()
# Out:
#            Inches  Price_euros  column1
# count  912.000000   912.000000      0.0
# mean    14.982785  1116.964013      NaN
# std      1.417299   681.619330      NaN
# min     10.100000   191.900000      NaN
# 25%     14.000000   598.000000      NaN
# 50%     15.600000   979.000000      NaN
# 75%     15.600000  1476.332500      NaN
# max     18.400000  5499.000000      NaN

# %%
#eliminamos column1 tras ver que son todo Nan
train_raw= train_raw.drop("column1", axis=1)

# %%
train_raw
# Out:
#           Company                               Product   TypeName  Inches  \
# laptop_ID
# 1104         Acer                        Aspire ES1-523   Notebook    15.6
# 114          Dell                                XPS 13  Ultrabook    13.3
# 172          Acer                       Aspire A517-51G   Notebook    17.3
# 918            HP                         Elitebook 820    Netbook    12.5
# 447        Lenovo                     IdeaPad 320-15AST   Notebook    17.3
# ...           ...                                   ...        ...     ...
# 996        Lenovo                     IdeaPad 320-15ABR   Notebook    15.6
# 731          Dell                          Alienware 17     Gaming    17.3
# 276          Asus                             Rog Strix     Gaming    17.3
# 585           MSI                          GT73VR Titan     Gaming    17.3
# 1173           HP  15-bw002nv (A6-9220/4GB/256GB/Radeon   Notebook    15.6
#
# ...

# %%
#De weight separamos los dos últimos términos para ver si son todo kg
#train_raw[['peso', 'magnitud']] = df['weight'].str.split('-', expand=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_155388\916895544.py in <module>
#       1 #De weight separamos los dos últimos términos para ver si son todo kg
# ----> 2 train_raw[['peso', 'magnitud']] = df['weight'].str.split('-', expand=True)
#
# NameError: name 'df' is not defined

# %%
train_raw[['peso', 'magnitud']] = train_raw['Weight'].str.extract(r'(\d+)(\w+)')

# %%
train_raw
# Out:
#           Company                               Product   TypeName  Inches  \
# laptop_ID
# 1104         Acer                        Aspire ES1-523   Notebook    15.6
# 114          Dell                                XPS 13  Ultrabook    13.3
# 172          Acer                       Aspire A517-51G   Notebook    17.3
# 918            HP                         Elitebook 820    Netbook    12.5
# 447        Lenovo                     IdeaPad 320-15AST   Notebook    17.3
# ...           ...                                   ...        ...     ...
# 996        Lenovo                     IdeaPad 320-15ABR   Notebook    15.6
# 731          Dell                          Alienware 17     Gaming    17.3
# 276          Asus                             Rog Strix     Gaming    17.3
# 585           MSI                          GT73VR Titan     Gaming    17.3
# 1173           HP  15-bw002nv (A6-9220/4GB/256GB/Radeon   Notebook    15.6
#
# ...

# %%
#Vemos si hay magnitud más allá de kg
valores_unicos_magnitud = train_raw['magnitud'].unique()
valores_unicos_magnitud
# Out:
# array(['kg'], dtype=object)

# %%
#eliminar columnas que no aportan nada
train_raw.drop(["Weight", "magnitud"], axis=1)
# Out:
#           Company                               Product   TypeName  Inches  \
# laptop_ID
# 1104         Acer                        Aspire ES1-523   Notebook    15.6
# 114          Dell                                XPS 13  Ultrabook    13.3
# 172          Acer                       Aspire A517-51G   Notebook    17.3
# 918            HP                         Elitebook 820    Netbook    12.5
# 447        Lenovo                     IdeaPad 320-15AST   Notebook    17.3
# ...           ...                                   ...        ...     ...
# 996        Lenovo                     IdeaPad 320-15ABR   Notebook    15.6
# 731          Dell                          Alienware 17     Gaming    17.3
# 276          Asus                             Rog Strix     Gaming    17.3
# 585           MSI                          GT73VR Titan     Gaming    17.3
# 1173           HP  15-bw002nv (A6-9220/4GB/256GB/Radeon   Notebook    15.6
#
# ...

# %%
#Verificamos si Opsys es solo Windows 10 o si efectivamente hay más sistemas operativos distintos, tras comprobarlo vemos que sí
valores_unicos = train_raw['OpSys'].unique()
valores_unicos
# Out:
# array(['Windows 10', 'No OS', 'Linux', 'Mac OS X', 'Windows 7',
#        'Chrome OS', 'macOS', 'Windows 10 S', 'Android'], dtype=object)

# %%
train_raw['OpSys'] = train_raw['OpSys'].replace('No', 'NA')
train_raw['OpSys'] = train_raw['OpSys'].replace('Mac OS ', 'macOS ')
train_raw['OpSys'] = train_raw['OpSys'].replace('Chrome OS', 'Chrome')
train_raw['OpSys'] = train_raw['OpSys'].replace('10 S', '10S')

# %%
train_raw['OpSys'] = train_raw['OpSys'].str.strip().replace('Mac OS', 'macOS')

# %%
train_raw['OpSys'] = train_raw['OpSys'].replace(r'\s*Mac\s*OS\s*', 'macOS', regex=True)
train_raw['OpSys'] = train_raw['OpSys'].replace('macOSX', 'macOS X')

# %%
train_raw['OpSys'] = train_raw['OpSys'].replace(r'Windows\s*10\s*S', 'Windows 10S', regex=True)

# %%
valores_unicos = train_raw['OpSys'].unique()
valores_unicos
# Out:
# array(['Windows 10', 'NA', 'Linux', 'macOS X', 'Windows 7', 'Chrome',
#        'macOS', 'Windows 10S', 'Android'], dtype=object)

# %%
# Dividir la columna 'OpSys' utilizando un espacio en blanco como separador
train_raw[['SO', 'modso']] = train_raw['OpSys'].str.split(' ', expand=True)
# Out:
#           Company                               Product   TypeName  Inches  \
# laptop_ID
# 1104         Acer                        Aspire ES1-523   Notebook    15.6
# 114          Dell                                XPS 13  Ultrabook    13.3
# 172          Acer                       Aspire A517-51G   Notebook    17.3
# 918            HP                         Elitebook 820    Netbook    12.5
# 447        Lenovo                     IdeaPad 320-15AST   Notebook    17.3
# ...           ...                                   ...        ...     ...
# 996        Lenovo                     IdeaPad 320-15ABR   Notebook    15.6
# 731          Dell                          Alienware 17     Gaming    17.3
# 276          Asus                             Rog Strix     Gaming    17.3
# 585           MSI                          GT73VR Titan     Gaming    17.3
# 1173           HP  15-bw002nv (A6-9220/4GB/256GB/Radeon   Notebook    15.6
#
# ...

# %%
train_raw
# Out:
#           Company                               Product   TypeName  Inches  \
# laptop_ID
# 1104         Acer                        Aspire ES1-523   Notebook    15.6
# 114          Dell                                XPS 13  Ultrabook    13.3
# 172          Acer                       Aspire A517-51G   Notebook    17.3
# 918            HP                         Elitebook 820    Netbook    12.5
# 447        Lenovo                     IdeaPad 320-15AST   Notebook    17.3
# ...           ...                                   ...        ...     ...
# 996        Lenovo                     IdeaPad 320-15ABR   Notebook    15.6
# 731          Dell                          Alienware 17     Gaming    17.3
# 276          Asus                             Rog Strix     Gaming    17.3
# 585           MSI                          GT73VR Titan     Gaming    17.3
# 1173           HP  15-bw002nv (A6-9220/4GB/256GB/Radeon   Notebook    15.6
#
# ...
