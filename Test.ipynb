# %%
# %run Limpieza.ipynb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 912 entries, 1104 to 1173
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           912 non-null    object
#  1   Product           912 non-null    object
#  2   TypeName          912 non-null    object
#  3   Inches            912 non-null    float64
#  4   ScreenResolution  912 non-null    object
#  5   Cpu               912 non-null    object
#  6   Ram               912 non-null    object
#  7   Memory            912 non-null    object
#  8   Gpu               912 non-null    object
#  9   OpSys             912 non-null    object
#  10  Weight            912 non-null    object
#  11  Price_euros       912 non-null    float64
#  12  column1           0 non-null      float64
# dtypes: float64(3), object(10)
# memory usage: 99.8+ KB

# %%
import seaborn as sns

# %%
train_raw
# Out:
#           Company                               Product   TypeName  Inches  \
# laptop_ID
# 1104         Acer                        Aspire ES1-523   Notebook    15.6
# 114          Dell                                XPS 13  Ultrabook    13.3
# 172          Acer                       Aspire A517-51G   Notebook    17.3
# 918            HP                         Elitebook 820    Netbook    12.5
# 447        Lenovo                     IdeaPad 320-15AST   Notebook    17.3
# ...           ...                                   ...        ...     ...
# 996        Lenovo                     IdeaPad 320-15ABR   Notebook    15.6
# 731          Dell                          Alienware 17     Gaming    17.3
# 276          Asus                             Rog Strix     Gaming    17.3
# 585           MSI                          GT73VR Titan     Gaming    17.3
# 1173           HP  15-bw002nv (A6-9220/4GB/256GB/Radeon   Notebook    15.6
#
#                            ScreenResolution                           Cpu  \
# laptop_ID
# 1104                               1366x768     AMD A8-Series 7410 2.2GHz
# 114        Quad HD+ / Touchscreen 3200x1800    Intel Core i7 7560U 2.4GHz
# 172             IPS Panel Full HD 1920x1080    Intel Core i5 8250U 1.6GHz
# 918                       Full HD 1920x1080    Intel Core i7 7500U 2.7GHz
# 447                                1600x900     AMD A6-Series 9220 2.5GHz
# ...                                     ...                           ...
# 996                       Full HD 1920x1080   AMD A12-Series 9720P 3.6GHz
# 731                   4K Ultra HD 3840x2160   Intel Core i7 7700HQ 2.8GHz
# 276                       Full HD 1920x1080           AMD Ryzen 1700 3GHz
# 585                       Full HD 1920x1080   Intel Core i7 7820HK 2.9GHz
# 1173                      Full HD 1920x1080  AMD A6-Series A6-9220 2.5GHz
#
#             Ram                Memory                           Gpu  \
# laptop_ID
# 1104        4GB             500GB HDD                 AMD Radeon R5
# 114         8GB             256GB SSD  Intel Iris Plus Graphics 640
# 172         8GB             256GB SSD          Nvidia GeForce MX150
# 918         8GB             512GB SSD         Intel HD Graphics 620
# 447         8GB               1TB HDD                 AMD Radeon R4
# ...         ...                   ...                           ...
# 996         6GB             256GB SSD                AMD Radeon 530
# 731        32GB    1TB SSD +  1TB HDD       Nvidia GeForce GTX 1070
# 276        16GB  256GB SSD +  1TB HDD             AMD Radeon RX 580
# 585        16GB  512GB SSD +  1TB HDD       Nvidia GeForce GTX 1070
# 1173        4GB             256GB SSD                AMD Radeon 520
#
#                 OpSys  Weight  Price_euros peso magnitud       SO modso
# laptop_ID
# 1104       Windows 10   2.4kg       387.00    4       kg  Windows    10
# 114        Windows 10  1.23kg      1379.00   23       kg  Windows    10
# 172        Windows 10     3kg       854.00    3       kg  Windows    10
# 918        Windows 10  1.26kg      1483.00   26       kg  Windows    10
# 447        Windows 10   2.8kg       519.00    8       kg  Windows    10
# ...               ...     ...          ...  ...      ...      ...   ...
# 996        Windows 10   2.2kg       549.00    2       kg  Windows    10
# 731        Windows 10  4.36kg      3659.40   36       kg  Windows    10
# 276        Windows 10   3.2kg      1549.00    2       kg  Windows    10
# 585        Windows 10  4.14kg      2729.00   14       kg  Windows    10
# 1173       Windows 10  1.91kg       478.89   91       kg  Windows    10
#
# [912 rows x 16 columns]

# %%
train_modelo=train_raw[["Company","Inches", "peso","Price_euros"]]
train_modelo
# Out:
#           Company  Inches peso  Price_euros
# laptop_ID
# 1104         Acer    15.6    4       387.00
# 114          Dell    13.3   23      1379.00
# 172          Acer    17.3    3       854.00
# 918            HP    12.5   26      1483.00
# 447        Lenovo    17.3    8       519.00
# ...           ...     ...  ...          ...
# 996        Lenovo    15.6    2       549.00
# 731          Dell    17.3   36      3659.40
# 276          Asus    17.3    2      1549.00
# 585           MSI    17.3   14      2729.00
# 1173           HP    15.6   91       478.89
#
# [912 rows x 4 columns]

# %%
#columnas

x=train_modelo[["Inches", "peso"]]
x
# Out:
#            Inches peso
# laptop_ID
# 1104         15.6    4
# 114          13.3   23
# 172          17.3    3
# 918          12.5   26
# 447          17.3    8
# ...           ...  ...
# 996          15.6    2
# 731          17.3   36
# 276          17.3    2
# 585          17.3   14
# 1173         15.6   91
#
# [912 rows x 2 columns]

# %%
#target variable
y=train_modelo[["Price_euros"]]
y
# Out:
#            Price_euros
# laptop_ID
# 1104            387.00
# 114            1379.00
# 172             854.00
# 918            1483.00
# 447             519.00
# ...                ...
# 996             549.00
# 731            3659.40
# 276            1549.00
# 585            2729.00
# 1173            478.89
#
# [912 rows x 1 columns]

# %%
#Entrenamiento del modelo

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.30, random_state = 42)

# %%
print("Total features shape:", x.shape)
print("Train features shape:", x_train.shape)
print("Train target shape:", y_train.shape)
print("Test features shape:", x_test.shape)
print("Test target shape:", y_test.shape)
# Out:
# Total features shape: (912, 2)
# Train features shape: (638, 2)
# Train target shape: (638, 1)
# Test features shape: (274, 2)
# Test target shape: (274, 1)

# %%
#importing the Linear Regression Algorithm
from sklearn.linear_model import LinearRegression

# %%
#creating LinearRegression Object
lm = LinearRegression()

# %%
#Training the Data Model
lm.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#Evaluo el modelo
print(lm.intercept_)
# Out:
# [738.53557959]

# %%
print(lm.coef_)
# Out:
# [[23.34935615  0.6235249 ]]

# %%
x_test
# Out:
#            Inches peso
# laptop_ID
# 636          15.6    2
# 23           15.6   86
# 28           15.6    2
# 672          17.3    7
# 1251         17.3    7
# ...           ...  ...
# 792          15.6    2
# 1119         15.6    4
# 1271         14.0    9
# 462          11.6   47
# 1311         15.6    6
#
# [274 rows x 2 columns]

# %%
predictions = lm.predict(x_test)
predictions
# Out:
# array([[1104.03258537],
#        [1156.4086766 ],

# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_156132\3170194530.py in <module>
# ----> 1 sns.scatterplot(x=y_test, y=predictions)
#
# c:\Users\IS\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\relational.py in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     740
#     741     variables = _ScatterPlotter.get_semantics(locals())
# --> 742     p = _ScatterPlotter(data=data, variables=variables, legend=legend)
#     743
#     744     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#
# c:\Users\IS\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\relational.py in __init__(self, data, variables, legend)
#     536         )
#     537
# --> 538         super().__init__(data=data, variables=variables)
#     539
#     540         self.legend = legend
#
# c:\Users\IS\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\_oldcore.py in __init__(self, data, variables)
#     638         # information for numeric axes would be information about log scales.
#     639         self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 640         self.assign_variables(data, variables)
#     641
#     642         for var, cls in self._semantic_mappings.items():
#
# c:\Users\IS\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\_oldcore.py in assign_variables(self, data, variables)
#     700             self.input_format = "long"
#     701             plot_data, variables = self._assign_variables_longform(
# --> 702                 data, **variables,
#     703             )
#     704
#
# c:\Users\IS\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\_oldcore.py in _assign_variables_longform(self, data, **kwargs)
#     960         # Construct a tidy plot DataFrame. This will convert a number of
#     961         # types automatically, aligning on index in case of pandas objects
# --> 962         plot_data = pd.DataFrame(plot_data)
#     963
#     964         # Reduce the variables dictionary to fields with valid data
#
# c:\Users\IS\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# c:\Users\IS\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     463
#     464     return arrays_to_mgr(
# --> 465         arrays, data_names, index, columns, dtype=dtype, typ=typ, consolidate=copy
#     466     )
#     467
#
# c:\Users\IS\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity, typ, consolidate)
#     117         # figure out the index, if necessary
#     118         if index is None:
# --> 119             index = _extract_index(arrays)
#     120         else:
#     121             index = ensure_index(index)
#
# c:\Users\IS\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\internals\construction.py in _extract_index(data)
#     623
#     624         if not indexes and not raw_lengths:
# --> 625             raise ValueError("If using all scalar values, you must pass an index")
#     626
#     627         if have_series:
#
# ValueError: If using all scalar values, you must pass an index
